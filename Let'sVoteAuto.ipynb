# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters 
input_size = 784 # 28x28
hidden_size = 500
hidden_size2 = 200
num_classes = 10
num_epochs = 2
batch_size = 100
learning_rate = 0.001
num_nn = 10

# MNIST dataset 
train_dataset = torchvision.datasets.MNIST(root='./data', 
                                           train=True, 
                                           transform=transforms.ToTensor(),  
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='./data', 
                                          train=False, 
                                          transform=transforms.ToTensor())

# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False)

examples = iter(test_loader)
example_data, example_targets = examples.next()

for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(example_data[i][0], cmap='gray')
plt.show()

# Fully connected neural network with one hidden layer
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.input_size = input_size
        self.l1 = nn.Linear(input_size, hidden_size) 
        self.l2 = nn.Linear(hidden_size, hidden_size2) 
        self.l3 = nn.Linear(hidden_size2, num_classes)  
        self.relu = nn.ReLU()
    
    def forward(self, x):
        out = self.l1(x)
        out = self.relu(out)
        out = self.l2(out)
        out = self.relu(out)
        out = self.l3(out)
        # no activation and no softmax at the end
        return out
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# Done!
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
models = []
criterions = []
optimizers = []
for x in range(num_nn):
  models.append(NeuralNet(input_size, hidden_size, num_classes).to(device))
  criterions.append(nn.CrossEntropyLoss())
  optimizers.append(torch.optim.Adam(models[x].parameters(), lr=learning_rate+(x/float(num_nn))*(0.0025-learning_rate)))
  n_total_steps = len(train_loader)
  for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):  
        # origin shape: [100, 1, 28, 28]
        # resized: [100, 784]
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        
        # Forward pass
        outputs = models[x](images)
        loss = criterions[x](outputs, labels)
        
        # Backward and optimize
        optimizers[x].zero_grad()
        loss.backward()
        optimizers[x].step()
        
        if (i+1) % 100 == 0:
            print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}' + "   nn number:" + str(x))


# Test the model
# In test phase, we don't need to compute gradients (for memory efficiency)
with torch.no_grad():
    n_correct = 0
    n_samples = 0
    for images, labels in test_loader:
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        outputs = models[0](images)/10.0
        for x in range(num_nn-1):
          outputs += models[x+1](images)/10.0
        # max returns (value ,index)
        _, predicted = torch.max(outputs.data, 1)
        n_samples += labels.size(0)
        n_correct += (predicted == labels).sum().item()

    acc = 100.0 * n_correct / n_samples
    print(f'Accuracy of the networks on the 10000 test images: {acc} %')
# Out:
# Epoch [1/2], Step [100/600], Loss: 0.4328   nn number:0
# Epoch [1/2], Step [200/600], Loss: 0.2369   nn number:0
# Epoch [1/2], Step [300/600], Loss: 0.2136   nn number:0
# Epoch [1/2], Step [400/600], Loss: 0.1396   nn number:0
# Epoch [1/2], Step [500/600], Loss: 0.2129   nn number:0
# Epoch [1/2], Step [600/600], Loss: 0.1523   nn number:0
# Epoch [2/2], Step [100/600], Loss: 0.0922   nn number:0
# Epoch [2/2], Step [200/600], Loss: 0.0499   nn number:0
# Epoch [2/2], Step [300/600], Loss: 0.2518   nn number:0
# Epoch [2/2], Step [400/600], Loss: 0.0456   nn number:0
# Epoch [2/2], Step [500/600], Loss: 0.1659   nn number:0
# Epoch [2/2], Step [600/600], Loss: 0.0685   nn number:0
# Epoch [1/2], Step [100/600], Loss: 0.4185   nn number:1
# Epoch [1/2], Step [200/600], Loss: 0.2423   nn number:1
# Epoch [1/2], Step [300/600], Loss: 0.1586   nn number:1
# Epoch [1/2], Step [400/600], Loss: 0.0941   nn number:1
# Epoch [1/2], Step [500/600], Loss: 0.0911   nn number:1
# Epoch [1/2], Step [600/600], Loss: 0.0783   nn number:1
# Epoch [2/2], Step [100/600], Loss: 0.1314   nn number:1
# Epoch [2/2], Step [200/600], Loss: 0.0923   nn number:1
# Epoch [2/2], Step [300/600], Loss: 0.0872   nn number:1
# Epoch [2/2], Step [400/600], Loss: 0.0829   nn number:1
# Epoch [2/2], Step [500/600], Loss: 0.1431   nn number:1
# Epoch [2/2], Step [600/600], Loss: 0.0881   nn number:1
# Epoch [1/2], Step [100/600], Loss: 0.2156   nn number:2
# Epoch [1/2], Step [200/600], Loss: 0.1470   nn number:2
# Epoch [1/2], Step [300/600], Loss: 0.1464   nn number:2
# Epoch [1/2], Step [400/600], Loss: 0.1361   nn number:2
# Epoch [1/2], Step [500/600], Loss: 0.1693   nn number:2
# Epoch [1/2], Step [600/600], Loss: 0.1324   nn number:2
# Epoch [2/2], Step [100/600], Loss: 0.1433   nn number:2
# Epoch [2/2], Step [200/600], Loss: 0.0548   nn number:2
# Epoch [2/2], Step [300/600], Loss: 0.0875   nn number:2
# Epoch [2/2], Step [400/600], Loss: 0.1533   nn number:2
# Epoch [2/2], Step [500/600], Loss: 0.0364   nn number:2
# Epoch [2/2], Step [600/600], Loss: 0.0586   nn number:2
# Epoch [1/2], Step [100/600], Loss: 0.3009   nn number:3
# Epoch [1/2], Step [200/600], Loss: 0.2383   nn number:3
# Epoch [1/2], Step [300/600], Loss: 0.2332   nn number:3
# Epoch [1/2], Step [400/600], Loss: 0.0431   nn number:3
# Epoch [1/2], Step [500/600], Loss: 0.1517   nn number:3
# Epoch [1/2], Step [600/600], Loss: 0.2534   nn number:3
# Epoch [2/2], Step [100/600], Loss: 0.0790   nn number:3
# Epoch [2/2], Step [200/600], Loss: 0.1867   nn number:3
# Epoch [2/2], Step [300/600], Loss: 0.1057   nn number:3
# Epoch [2/2], Step [400/600], Loss: 0.0478   nn number:3
# Epoch [2/2], Step [500/600], Loss: 0.1491   nn number:3
# Epoch [2/2], Step [600/600], Loss: 0.1100   nn number:3
# Epoch [1/2], Step [100/600], Loss: 0.2200   nn number:4
# Epoch [1/2], Step [200/600], Loss: 0.2009   nn number:4
# Epoch [1/2], Step [300/600], Loss: 0.2390   nn number:4
# Epoch [1/2], Step [400/600], Loss: 0.1598   nn number:4
# Epoch [1/2], Step [500/600], Loss: 0.0343   nn number:4
# Epoch [1/2], Step [600/600], Loss: 0.1153   nn number:4
# Epoch [2/2], Step [100/600], Loss: 0.1008   nn number:4
# Epoch [2/2], Step [200/600], Loss: 0.0150   nn number:4
# Epoch [2/2], Step [300/600], Loss: 0.0787   nn number:4
# Epoch [2/2], Step [400/600], Loss: 0.0868   nn number:4
# Epoch [2/2], Step [500/600], Loss: 0.0545   nn number:4
# Epoch [2/2], Step [600/600], Loss: 0.1404   nn number:4
# Epoch [1/2], Step [100/600], Loss: 0.3624   nn number:5
# Epoch [1/2], Step [200/600], Loss: 0.1687   nn number:5
# Epoch [1/2], Step [300/600], Loss: 0.2584   nn number:5
# Epoch [1/2], Step [400/600], Loss: 0.2525   nn number:5
# Epoch [1/2], Step [500/600], Loss: 0.1158   nn number:5
# Epoch [1/2], Step [600/600], Loss: 0.1034   nn number:5
# Epoch [2/2], Step [100/600], Loss: 0.0320   nn number:5
# Epoch [2/2], Step [200/600], Loss: 0.1758   nn number:5
# Epoch [2/2], Step [300/600], Loss: 0.0705   nn number:5
# Epoch [2/2], Step [400/600], Loss: 0.0597   nn number:5
# Epoch [2/2], Step [500/600], Loss: 0.1023   nn number:5
# Epoch [2/2], Step [600/600], Loss: 0.1678   nn number:5
# Epoch [1/2], Step [100/600], Loss: 0.2400   nn number:6
# Epoch [1/2], Step [200/600], Loss: 0.2163   nn number:6
# Epoch [1/2], Step [300/600], Loss: 0.1020   nn number:6
# Epoch [1/2], Step [400/600], Loss: 0.1474   nn number:6
# Epoch [1/2], Step [500/600], Loss: 0.1076   nn number:6
# Epoch [1/2], Step [600/600], Loss: 0.0711   nn number:6
# Epoch [2/2], Step [100/600], Loss: 0.0726   nn number:6
# Epoch [2/2], Step [200/600], Loss: 0.0510   nn number:6
# Epoch [2/2], Step [300/600], Loss: 0.0684   nn number:6
# Epoch [2/2], Step [400/600], Loss: 0.0549   nn number:6
# Epoch [2/2], Step [500/600], Loss: 0.0360   nn number:6
# Epoch [2/2], Step [600/600], Loss: 0.0830   nn number:6
# Epoch [1/2], Step [100/600], Loss: 0.2820   nn number:7
# Epoch [1/2], Step [200/600], Loss: 0.1695   nn number:7
# Epoch [1/2], Step [300/600], Loss: 0.1104   nn number:7
# Epoch [1/2], Step [400/600], Loss: 0.2702   nn number:7
# Epoch [1/2], Step [500/600], Loss: 0.1754   nn number:7
# Epoch [1/2], Step [600/600], Loss: 0.2519   nn number:7
# Epoch [2/2], Step [100/600], Loss: 0.0590   nn number:7
# Epoch [2/2], Step [200/600], Loss: 0.1513   nn number:7
# Epoch [2/2], Step [300/600], Loss: 0.0795   nn number:7
# Epoch [2/2], Step [400/600], Loss: 0.0088   nn number:7
# Epoch [2/2], Step [500/600], Loss: 0.0755   nn number:7
# Epoch [2/2], Step [600/600], Loss: 0.0601   nn number:7
# Epoch [1/2], Step [100/600], Loss: 0.2225   nn number:8
# Epoch [1/2], Step [200/600], Loss: 0.1248   nn number:8
# Epoch [1/2], Step [300/600], Loss: 0.1435   nn number:8
# Epoch [1/2], Step [400/600], Loss: 0.1884   nn number:8
# Epoch [1/2], Step [500/600], Loss: 0.0734   nn number:8
# Epoch [1/2], Step [600/600], Loss: 0.1766   nn number:8
# Epoch [2/2], Step [100/600], Loss: 0.1075   nn number:8
# Epoch [2/2], Step [200/600], Loss: 0.0410   nn number:8
# Epoch [2/2], Step [300/600], Loss: 0.1021   nn number:8
# Epoch [2/2], Step [400/600], Loss: 0.0236   nn number:8
# Epoch [2/2], Step [500/600], Loss: 0.2116   nn number:8
# Epoch [2/2], Step [600/600], Loss: 0.0866   nn number:8
# Epoch [1/2], Step [100/600], Loss: 0.2918   nn number:9
# Epoch [1/2], Step [200/600], Loss: 0.1726   nn number:9
# Epoch [1/2], Step [300/600], Loss: 0.1779   nn number:9
# Epoch [1/2], Step [400/600], Loss: 0.1489   nn number:9
# Epoch [1/2], Step [500/600], Loss: 0.1632   nn number:9
# Epoch [1/2], Step [600/600], Loss: 0.1774   nn number:9
# Epoch [2/2], Step [100/600], Loss: 0.1084   nn number:9
# Epoch [2/2], Step [200/600], Loss: 0.0442   nn number:9
# Epoch [2/2], Step [300/600], Loss: 0.1197   nn number:9
# Epoch [2/2], Step [400/600], Loss: 0.1075   nn number:9
# Epoch [2/2], Step [500/600], Loss: 0.0921   nn number:9
# Epoch [2/2], Step [600/600], Loss: 0.0056   nn number:9
# Accuracy of the networks on the 10000 test images: 98.18 %

# %%
#experimental model.
model1 = NeuralNet(input_size, hidden_size, num_classes).to(device)

# Loss and optimizer
criterion1 = nn.CrossEntropyLoss()
optimizer1 = torch.optim.Adam(model1.parameters(), lr=learning_rate)  

# Train the model
n_total_steps = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):  
        # origin shape: [100, 1, 28, 28]
        # resized: [100, 784]
        images1 = images.reshape(-1, 28*28).to(device)
        labels1 = labels.to(device)
        
        # Forward pass
        outputs1 = model1(images1)
        loss1 = criterion1(outputs1, labels1)
        
        # Backward and optimize
        optimizer1.zero_grad()
        loss1.backward()
        optimizer1.step()
        
        if (i+1) % 100 == 0:
            print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss1.item():.4f}')

with torch.no_grad():
    n_correct = 0
    n_samples = 0
    for images, labels in test_loader:
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        outputs = model1(images)
        # max returns (value ,index)
        _, predicted = torch.max(outputs.data, 1)
        n_samples += labels.size(0)
        n_correct += (predicted == labels).sum().item()

    acc = 100.0 * n_correct / n_samples
    print(f'Accuracy of the network on the 10000 test images: {acc} %')
# Out:
# Epoch [1/2], Step [100/600], Loss: 0.3895
# Epoch [1/2], Step [200/600], Loss: 0.1809
# Epoch [1/2], Step [300/600], Loss: 0.2421
# Epoch [1/2], Step [400/600], Loss: 0.2131
# Epoch [1/2], Step [500/600], Loss: 0.1103
# Epoch [1/2], Step [600/600], Loss: 0.1056
# Epoch [2/2], Step [100/600], Loss: 0.1174
# Epoch [2/2], Step [200/600], Loss: 0.0648
# Epoch [2/2], Step [300/600], Loss: 0.0792
# Epoch [2/2], Step [400/600], Loss: 0.0851
# Epoch [2/2], Step [500/600], Loss: 0.0743
# Epoch [2/2], Step [600/600], Loss: 0.0694
# Accuracy of the network on the 10000 test images: 97.33 %
